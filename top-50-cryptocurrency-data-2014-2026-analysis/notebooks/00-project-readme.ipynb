# %% [markdown]
# # Data Source and Attribution
#
# This project utilizes the **Crypto Data (2014-2026)** dataset provided by **Kaushal Nandania** on Kaggle.
#
# ### Dataset Overview
# *   **Source:** [Kaggle - Crypto Data (2014-2026)](https://www.kaggle.com)
# *   **Author:** [Kaushal Nandania](https://www.kaggle.com)
# *   **License:** [CC BY-SA 4.0](https://creativecommons.org)
# *   **Format:** CSV files containing historical cryptocurrency price data (Open, High, Low, Close, Volume).
